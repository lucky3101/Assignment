# %% [markdown]
# # Jupyter Notebook Assignment

# %% [markdown]
# This is introduction to Jupyter Notebook Assignment

# %% [markdown]
# Data science languages
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# Data scientists libraries
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. Tensorflow

# %% [markdown]
# | Data Science Tools |
# | ---------------- |
# | Jupyter Notebook |
# | RStudio |
# | VS Code |

# %% [markdown]
# Arithmetic expression example

# %%
10*(3+2)
# Out:
# 50

# %%
# Converting 600 minutes to hours
600/60
# Out:
# 10.0

# %% [markdown]
# Objectives
#
# - List popular languages for Data Science
# - List common used libraries used by Data Scientists
# - Tabulate data science tools
# - Evaluate arithmetic expressions

# %% [markdown]
# Author
#
# **Lucky Singh Shekhawat**
